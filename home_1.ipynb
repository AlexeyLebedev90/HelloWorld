# %%
import sqlite3
import requests
import pandas as pd
all_result = []
offset_ = 1
limit_ = 100
while True: 
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
    res = requests.get(url)
    objects_data = res.json()
    objects_list = objects_data.get('data').get('list')
    all_result.extend([x.get('objId') for x in objects_list])
    if len (objects_list) == 0:
        break
    offset_+=limit_
all_result
# Out:
# [29678,
#  13383,
#  13391,
#  13397,
#  13398,
#  13399,
#  36912,
#  44076,
#  23494,
#  27476,
#  10891,
#  39175,
#  39174,
#  39176,
#  27049,
#  41420,
#  41421,
#  30292,
#  19414,
#  19457,
#  18709,
#  18708,
#  21537,
#  21534,
#  21536,
#  21535,
#  41625,
#  42192,
#  27542,
#  20524,
#  29184,
#  24093,
#  27802,
#  27806,
#  27808,
#  27801,
#  23864,
#  27798,
#  27803,
#  23863,
#  23862,
#  45249,
#  21720,
#  33899,
#  17712,
#  17707,
#  33745,
#  44489,
#  44474,
#  44621,
#  46571,
#  15888,
#  15885,
#  15889,
#  15891,
#  15890,
#  15886,
#  35324,
#  45256,
#  41615,
#  41616,
#  41619,
#  24817,
#  41617,
#  24820,
#  41618,
#  41612,
#  41613,
#  41614,
#  41620,
#  24819,
#  41621,
#  24818,
#  45772,
#  18136,
#  44752,
#  32082,
#  32080,
#  37465,
#  33525,
#  3148,
#  33095,
#  33096,
#  33097,
#  33106,
#  33183,
#  33186,
#  33188,
#  33193,
#  33197,
#  33213,
#  33123,
#  33229,
#  33235,
#  33237,
#  33178,
#  33190,
#  33191,
#  33199,
#  33212,
#  33198,
#  33211,
#  33212,
#  33221,
#  33222,
#  33226,
#  33237,
#  33123,
#  33193,
#  33199,
#  33204,
#  33218,
#  33219,
#  33229,
#  33235,
#  33134,
#  33137,
#  33146,
#  33150,
#  33151,
#  33154,
#  33156,
#  33157,
#  33163,
#  33166,
#  33171,
#  33135,
#  33140,
#  33143,
#  33148,
#  33155,
#  33158,
#  33162,
#  33168,
#  33170,
#  33138,
#  33174,
#  33098,
#  33099,
#  33100,
#  33101,
#  33153,
#  33159,
#  33173,
#  33175,
#  33176,
#  33233,
#  33180,
#  33185,
#  33203,
#  33210,
#  33216,
#  33225,
#  33227,
#  33228,
#  33236,
#  33167,
#  33179,
#  33182,
#  33187,
#  33189,
#  33195,
#  33208,
#  33209,
#  33214,
#  33223,
#  33231,
#  33232,
#  33139,
#  33145,
#  33107,
#  33152,
#  33160,
#  33161,
#  33164,
#  33165,
#  33169,
#  33172,
#  33181,
#  33184,
#  33196,
#  33200,
#  33201,
#  33202,
#  33205,
#  33206,
#  33207,
#  33220,
#  33230,
#  33234,
#  33136,
#  33141,
#  33142,
#  33144,
#  33147,
#  33149,
#  16113,
#  43140,
#  34228,
#  4024,
#  4024,
#  4023,
#  4025,
#  35042,
#  47499,
#  47500,
#  47496,
#  47497,
#  47498,
#  37725,
#  41385,
#  37726,
#  41386,
#  37727,
#  33779,
#  33780,
#  33781,
#  33782,
#  33783,
#  31821,
#  28211,
#  27787,
#  28043,
#  28048,
#  27782,
#  28213,
#  27784,
#  27788,
#  28047,
#  28212,
#  28042,
#  28044,
#  28045,
#  27786,
#  27783,
#  28214,
#  28210,
#  28215,
#  28208,
#  28216,
#  28209,
#  28049,
#  27789,
#  28046,
#  27790,
#  39995,
#  45955,
#  23444,
#  42203,
#  28254,
#  28256,
#  28255,
#  46776,
#  44006,
#  46838,
#  45813,
#  42129,
#  27628,
#  27629,
#  27630,
#  27633,
#  27632,
#  27631,
#  34912,
#  37425,
#  39675,
#  43214,
#  42935,
#  36016,
#  37518,
#  37519,
#  37520,
#  23229,
#  26213,
#  26212,
#  46297,
#  47152,
#  47153,
#  31395,
#  31398,
#  31400,
#  31396,
#  31397,
#  31399,
#  23020,
#  23021,
#  23019,
#  23022,
#  21295,
#  21294,
#  21293,
#  21296,
#  2928,
#  43659,
#  43660,
#  43815,
#  8916,
#  8915,
#  8919,
#  8922,
#  8927,
#  8936,
#  8922,
#  8929,
#  8930,
#  8934,
#  8924,
#  8920,
#  8928,
#  8918,
#  8921,
#  8917,
#  8937,
#  8932,
#  8938,
#  28799,
#  26181,
#  26182,
#  26180,
#  28444,
#  35466,
#  35467,
#  35468,
#  31297,
#  32308,
#  28165,
#  28162,
#  28166,
#  28164,
#  28163,
#  28167,
#  40419,
#  7514,
#  32401,
#  32402,
#  32403,
#  32406,
#  32404,
#  32405,
#  32407,
#  36377,
#  3642,
#  3639,
#  3640,
#  3645,
#  3643,
#  3636,
#  3644,
#  3630,
#  3633,
#  3637,
#  3638,
#  3641,
#  3632,
#  27677,
#  44439,
#  44441,
#  44440,
#  44442,
#  44443,
#  44444,
#  44445,
#  31230,
#  31231,
#  30008,
#  37183,
#  38553,
#  38604,
#  35694,
#  43853,
#  46347,
#  36761,
#  36897,
#  36190,
#  42259,
#  43177,
#  38969,
#  41083,
#  38441,
#  43893,
#  37840,
#  37690,
#  40819,
#  36438,
#  36898,
#  45857,
#  45044,
#  34884,
#  42843,
#  35970,
#  39316,
#  38194,
#  42058,
#  35410,
#  37034,
#  45868,
#  37712,
#  34533,
#  42280,
#  45867,
#  35971,
#  45867,
#  38990,
#  41354,
#  41355,
#  41356,
#  41358,
#  41357,
#  41359,
#  42385,
#  44002,
#  44003,
#  24317,
#  24318,
#  24319,
#  24316,
#  3373,
#  22496,
#  23275,
#  23276,
#  23279,
#  23278,
#  23277,
#  23272,
#  23273,
#  23274,
#  20703,
#  20702,
#  20706,
#  20701,
#  20705,
#  3986,
#  16824,
#  26134,
#  35599,
#  26133,
#  27149,
#  27148,
#  24211,
#  36281,
#  42434,
#  41872,
#  24539,
#  24540,
#  30973,
#  43506,
#  43711,
#  39287,
#  10533,
#  10534,
#  10535,
#  30176,
#  34891,
#  24590,
#  38320,
#  45048,
#  38321,
#  38322,
#  45050,
#  45049,
#  39334,
#  39335,
#  39336,
#  38324,
#  45051,
#  38326,
#  45054,
#  36029,
#  38323,
#  38325,
#  45053,
#  45052,
#  36028,
#  36027,
#  42790,
#  42791,
#  42792,
#  47435,
#  41047,
#  45409,
#  44485,
#  37847,
#  43190,
#  26676,
#  32145,
#  47564,
#  32194,
#  32182,
#  32181,
#  32144,
#  18173,
#  33459,
#  33456,
#  33457,
#  33458,
#  43297,
#  38685,
#  38686,
#  38687,
#  45981,
#  41404,
#  46835,
#  13204,
#  13203,
#  9189,
#  25576,
#  41000,
#  40008,
#  44055,
#  27226,
#  45214,
#  42527,
#  46673,
#  44084,
#  42428,
#  33609,
#  46233,
#  20030,
#  36986,
#  41389,
#  41246,
#  41221,
#  40392,
#  41222,
#  41390,
#  41391,
#  36987,
#  41223,
#  36988,
#  40393,
#  41398,
#  36994,
#  41397,
#  41402,
#  41400,
#  41247,
#  41392,
#  41225,
#  36990,
#  36992,
#  41224,
#  36989,
#  41227,
#  41395,
#  36993,
#  41396,
#  41226,
#  36991,
#  41394,
#  41393,
#  41399,
#  41401,
#  40539,
#  45630,
#  45631,
#  44654,
#  46457,
#  46456,
#  46455,
#  46458,
#  46452,
#  46453,
#  46454,
#  22633,
#  31870,
#  42022,
#  44984,
#  44986,
#  44985,
#  43268,
#  15124,
#  15125,
#  13922,
#  21888,
#  41447,
#  43254,
#  19204,
#  20190,
#  32269,
#  26753,
#  22583,
#  22609,
#  22610,
#  22611,
#  22613,
#  22614,
#  22616,
#  22622,
#  22623,
#  22606,
#  22607,
#  22626,
#  22604,
#  22621,
#  22584,
#  22605,
#  22618,
#  22617,
#  22619,
#  22624,
#  22619,
#  22621,
#  22624,
#  28425,
#  32119,
#  42114,
#  13495,
#  31442,
#  31443,
#  31444,
#  34950,
#  44161,
#  41266,
#  43451,
#  41267,
#  40192,
#  43450,
#  43832,
#  43836,
#  45629,
#  45143,
#  45383,
#  45384,
#  25656,
#  25657,
#  44656,
#  32926,
#  8787,
#  11529,
#  11531,
#  8792,
#  11527,
#  11534,
#  13573,
#  13563,
#  13569,
#  13574,
#  13564,
#  13575,
#  13576,
#  13566,
#  13577,
#  13565,
#  13572,
#  13571,
#  13570,
#  13578,
#  13567,
#  47331,
#  46963,
#  46964,
#  46957,
#  46954,
#  47333,
#  47466,
#  46955,
#  47334,
#  46956,
#  47335,
#  37902,
#  37901,
#  37903,
#  37904,
#  37898,
#  37899,
#  37900,
#  43427,
#  22405,
#  32280,
#  30644,
#  30645,
#  30632,
#  30647,
#  30646,
#  30088,
#  851,
#  30144,
#  22540,
#  22544,
#  22518,
#  22543,
#  22519,
#  22533,
#  22532,
#  22536,
#  22534,
#  22531,
#  22530,
#  22527,
#  22542,
#  25079,
#  28539,
#  6388,
#  6393,
#  6392,
#  46375,
#  37742,
#  37733,
#  28036,
#  32611,
#  29010,
#  28980,
#  42911,
#  42355,
#  27384,
#  42610,
#  34898,
#  34899,
#  34900,
#  41943,
#  44681,
#  42581,
#  42354,
#  46110,
#  45821,
#  41274,
#  17823,
#  17824,
#  41626,
#  46017,
#  37263,
#  40085,
#  47583,
#  47584,
#  38034,
#  38035,
#  38036,
#  31327,
#  31328,
#  40084,
#  36904,
#  36903,
#  38486,
#  42477,
#  42246,
#  42475,
#  26035,
#  26031,
#  4923,
#  26034,
#  37467,
#  37469,
#  27838,
#  37204,
#  41230,
#  45747,
#  46244,
#  36062,
#  21626,
#  5284,
#  47322,
#  45532,
#  47600,
#  25238,
#  19438,
#  8224,
#  19437,
#  43063,
#  43064,
#  32084,
#  27917,
#  27918,
#  27916,
#  27924,
#  27925,
#  27919,
#  27923,
#  27920,
#  27922,
#  27921,
#  44007,
#  37757,
#  42170,
#  43627,
#  47398,
#  41668,
#  39770,
#  11302,
#  10415,
#  11657,
#  11638,
#  11095,
#  13669,
#  7196,
#  45352,
#  44762,
#  44058,
#  36460,
#  44059,
#  7199,
#  7197,
#  44060,
#  18754,
#  18753,
#  18757,
#  18761,
#  18762,
#  18755,
#  18756,
#  36707,
#  37072,
#  46721,
#  44757,
#  40756,
#  7198,
#  44061,
#  18759,
#  18758,
#  18763,
#  18764,
#  18760,
#  27145,
#  5120,
#  19053,
#  19054,
#  19050,
#  10351,
#  42594,
#  38847,
#  41106,
#  47318,
#  43932,
#  39811,
#  46229,
#  34698,
#  34699,
#  37167,
#  42797,
#  4692,
#  4693,
#  4694,
#  4695,
#  21740,
#  45731,
#  46570,
#  45920,
#  45626,
#  45953,
#  42213,
#  40742,
#  45915,
#  25725,
#  44781,
#  44778,
#  12793,
#  12792,
#  12791,
#  41772,
#  10590,
#  31817,
#  40478,
#  24731,
#  40479,
#  24730,
#  40480,
#  24732,
#  33558,
#  3224,
#  46604,
#  8670,
#  25298,
#  7531,
#  30123,
#  14007,
#  4781,
#  4782,
#  4783,
#  19929,
#  19926,
#  32343,
#  19930,
#  32344,
#  19925,
#  19927,
#  47303,
#  32345,
#  19924,
#  32348,
#  32346,
#  32347,
#  7139,
#  7136,
#  7135,
#  33247,
#  18884,
#  32629,
#  43501,
#  31021,
#  17398,
#  17395,
#  17405,
#  17410,
#  17411,
#  17406,
#  17409,
#  17399,
#  17397,
#  17403,
#  17404,
#  17407,
#  17407,
#  17408,
#  32603,
#  32604,
#  11018,
#  32605,
#  11020,
#  11016,
#  11019,
#  11025,
#  11021,
#  11023,
#  11022,
#  11026,
#  32606,
#  32608,
#  32607,
#  11024,
#  11017,
#  43491,
#  25252,
#  41834,
#  23556,
#  4654,
#  43675,
#  39317,
#  24234,
#  37859,
#  24222,
#  21402,
#  41944,
#  24070,
#  24082,
#  24085,
#  24090,
#  36567,
#  29439,
#  37371,
#  37372,
#  28563,
#  28530,
#  9588,
#  31298,
#  42059,
#  23733,
#  24498,
#  24501,
#  24502,
#  20507,
#  46821,
#  41147,
#  23551,
#  23550,
#  33238,
#  1527,
#  47547,
#  47548,
#  8652,
#  42903,
#  42904,
#  39000,
#  11725,
#  22183,
#  22178,
#  36846,
#  40676,
#  46139,
#  46140,
#  36660,
#  36661,
#  36664,
#  36663,
#  36665,
#  42929,
#  12963,
#  29451,
#  41649,
#  41648,
#  41647,
#  41644,
#  41645,
#  41650,
#  41651,
#  41656,
#  41646,
#  25099,
#  25100,
#  25096,
#  25097,
#  25098,
#  3333,
#  22720,
#  38360,
#  43811,
#  26158,
#  41658,
#  46237,
#  42638,
#  42635,
#  42637,
#  ...]

# %%
data = pd.DataFrame()
for id in all_result:
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{id}'
    res = requests.get(url)
    object_info = res.json()
res.json()
# Out:
# {'data': {'id': 45321,
#   'pdId': 516648,
#   'developer': {'devId': 2912,
#    'devShortCleanNm': '‹‹СЗ ‹‹СТРОЙ-НАДЕЖДА››',
#    'devShortNm': '‹‹СЗ ‹‹СТРОЙ-НАДЕЖДА››',
#    'devFullCleanNm': '‹‹СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ‹‹СТРОЙ-НАДЕЖДА››',
#    'problObjCnt': 0,
#    'buildObjCnt': 1,
#    'comissObjCnt': 7,
#    'regRegionDesc': 'Брянская область',
#    'devPhoneNum': '+7 (483) 274-56-60',
#    'devSite': 'www.saks32.ru',
#    'devEmail': 'saks_br@mail.ru',
#    'devInn': '3235015191',
#    'devOgrn': '1033231002694',
#    'devKpp': '325701001',
#    'devLegalAddr': 'Брянская область, город Брянск, улица Советская дом 49/1 офис 2',
#    'devFactAddr': 'Брянская обл, город Брянск, улица Советская, д.49/1, оф.2',
#    'lastRpdId': 623960,
#    'fundGuarantyFlg': 0,
#    'devOrgRegRegionCd': 32,
#    'devEmplMainFullNm': 'Киселев Сергей Иванович',
#    'developerGroupName': 'САКС',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroupId': 5724,
#    'objGuarantyEscrowFlg': 1,
#    'govFundFlg': 0},
#   'region': 32,
#   'address': 'г Брянск, улица Молодой Гвардии, строение Поз.1',
#   'floorMin': 11,
#   'floorMax': 11,
#   'objElemLivingCnt': 90,
#   'objReady100PercDt': '2023-03-31',
#   'wallMaterialShortDesc': 'Монолит-кирпич',
#   'objLkFinishTypeDesc': 'Без отделки',
#   'objLkFreePlanDesc': 'Нет',
#   'objElemParkingCnt': 0,
#   'objSquareLiving': 5288.4,
#   'rpdNum': '32-000336',
#   'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/53f63140-b570-47d2-957e-b87962adbdc0',
#   'rpdIssueDttm': '09-08-2022 12:43',
#   'objLkLatitude': '53.3129',
#   'objLkLongitude': '34.277',
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'objLkClassDesc': 'Типовой',
#   'loadDttm': '18-08-2022 01:24',
#   'photoRenderDTO': [{'objId': 45321,
#     'pdId': 516648,
#     'rpdId': 623960,
#     'devId': 2912,
#     'ordNum': 1,
#     'objRenderPhotoSize': 2209809,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/f55e6628-701f-468a-956d-6ef02c5d7637',
#     'objRenderPhotoDttm': '03-03-2022 12:12',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': '01__2.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '18-08-2022 01:06'},
#    {'objId': 45321,
#     'pdId': 516648,
#     'rpdId': 623960,
#     'devId': 2912,
#     'ordNum': 2,
#     'objRenderPhotoSize': 2741608,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/4a5e9804-f404-4596-be22-5468565bfabd',
#     'objRenderPhotoDttm': '03-03-2022 12:12',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': '02__21.jpg1.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '18-08-2022 01:06'},
#    {'objId': 45321,
#     'pdId': 516648,
#     'rpdId': 623960,
#     'devId': 2912,
#     'ordNum': 3,
#     'objRenderPhotoSize': 2061468,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/c8dbf87f-2164-4f15-92b1-898d227f0990',
#     'objRenderPhotoDttm': '03-03-2022 12:12',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': '03__22.jpg2.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '18-08-2022 01:06'}],
#   'objGuarantyEscrowFlg': 1,
#   'objectType': 'normal',
#   'miniUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/af2ae9e2-7745-4cc9-97bd-877ead32e4df',
#   'residentialBuildings': 1,
#   'newBuildingId': 125942,
#   'objFloorCnt': 11,
#   'objFlatCnt': 90,
#   'objFlatSq': '5288.4',
#   'objNonlivElemCnt': 0,
#   'quartography': {'objLivElem1KCnt': 36,
#    'objLivElem2KCnt': 36,
#    'objLivElem3KCnt': 18,
#    'objLivElem4KCnt': 0,
#    'objLivElemCnt': 90,
#    'objLivElemEntrCnt': 2,
#    'objLivElemEntrFloorAvg': 5},
#   'objStatus': 0,
#   'isAvailableWantLiveHere': True,
#   'objTransferPlanDt': '30-06-2023 12:00',
#   'objLivCeilingHeight': '2,76',
#   'objInfrstrBicycleLaneFlg': 0,
#   'objInfrstrPlaygrndCnt': 1,
#   'objInfrstrSportGroundCnt': 0,
#   'objInfrstrTrashAreaCnt': 1,
#   'objInfrstrObjPrkngCnt': 60,
#   'objInfrstrNotObjPrkngCnt': 0,
#   'objInfrstrRampFlg': 1,
#   'objInfrstrCurbLoweringFlg': 1,
#   'objElevatorWheelchairCnt': 0,
#   'objElevatorPassengerCnt': 0,
#   'objElevatorCargoCnt': 0,
#   'soldOutPerc': 0.0889683079948567,
#   'objPriceAvg': 68188,
#   'nonlivFirstFloor': 0,
#   'objectTransportInfo': [],
#   'conclusion': False,
#   'objLkSaleDepEmail': 'saks_br@mail.ru',
#   'objGreenHouseFlg': 0,
#   'objEnergyEffShortDesc': 'C',
#   'infrastructureIndexValue': 7},
#  'errcode': '0'}

# %%
object_info_df = pd.json_normalize(object_info)
data = data.append(object_info_df)
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_3012\1132042315.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(object_info_df)
#   errcode  data.id  data.pdId  data.developer.devId  \
# 0       0    45321     516648                  2912
#
#   data.developer.devShortCleanNm data.developer.devShortNm  \
# 0         ‹‹СЗ ‹‹СТРОЙ-НАДЕЖДА››    ‹‹СЗ ‹‹СТРОЙ-НАДЕЖДА››
#
#                        data.developer.devFullCleanNm  \
# 0  ‹‹СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ‹‹СТРОЙ-НАДЕЖДА››
#
#    data.developer.problObjCnt  data.developer.buildObjCnt  \
# 0                           0                           1
#
#    data.developer.comissObjCnt  ... data.objElevatorCargoCnt data.soldOutPerc  \
# 0                            7  ...                        0         0.088968
#
#   data.objPriceAvg data.nonlivFirstFloor data.objectTransportInfo  \
# 0            68188                     0                       []
#
#   data.conclusion data.objLkSaleDepEmail data.objGreenHouseFlg  \
# 0           False        saks_br@mail.ru                     0
#
#   data.objEnergyEffShortDesc  data.infrastructureIndexValue
# 0                          C                              7
#
# [1 rows x 91 columns]

# %%
data.to_pickle('First.pkl')
